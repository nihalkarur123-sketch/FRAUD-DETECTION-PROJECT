# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
df= pd.read_csv('AIML Dataset.csv')

# %%
df.head()
# Out:
#    step      type    amount  ... newbalanceDest  isFraud  isFlaggedFraud
# 0     1   PAYMENT   9839.64  ...            0.0        0               0
# 1     1   PAYMENT   1864.28  ...            0.0        0               0
# 2     1  TRANSFER    181.00  ...            0.0        1               0
# 3     1  CASH_OUT    181.00  ...            0.0        1               0
# 4     1   PAYMENT  11668.14  ...            0.0        0               0
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            str
#  2   amount          float64
#  3   nameOrig        str
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        str
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 534.0 MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (6362620, 11)

# %%
round((df["isFraud"].value_counts()[1]/df.shape[0])*100,2)
# Out:
# np.float64(0.13)

# %%
df["type"].value_counts().plot(kind='bar',title='transaction types',color='skyblue')
plt.xlabel('Transaction Types')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(np.log1p(df['amount']),bins=100,kde=True, color='green')
plt.title("transaction amt distribution(log scaled)")
plt.xlabel("log(amt+1)")
plt.show()

# %%
sns.boxplot(data=df[df['amount']<50000],x="isFraud",y="amount")
plt.title("amount vs fraud (under 50k)")
# Out:
# Text(0.5, 1.0, 'amount vs fraud (under 50k)')

# %%
df["balanceDiffOrig"]=df["oldbalanceOrg"]-df["newbalanceOrig"]
df["balanceDiffDest"]=df["newbalanceDest"]-df["oldbalanceDest"]

# %%
(df["balanceDiffOrig"]<0).sum()
# Out:
# np.int64(1399253)

# %%
(df["balanceDiffDest"]<0).sum()
# Out:
# np.int64(1238864)

# %%
df.drop(columns="step",inplace=True)

# %%
df.head()
# Out:
#        type    amount  ... balanceDiffOrig  balanceDiffDest
# 0   PAYMENT   9839.64  ...         9839.64              0.0
# 1   PAYMENT   1864.28  ...         1864.28              0.0
# 2  TRANSFER    181.00  ...          181.00              0.0
# 3  CASH_OUT    181.00  ...          181.00         -21182.0
# 4   PAYMENT  11668.14  ...        11668.14              0.0
#
# [5 rows x 12 columns]

# %%
top_senders=df["nameOrig"].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %%
top_recievers=df["nameDest"].value_counts().head(10)

# %%
top_recievers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_types=df[df["type"].isin(["TRANSFER","CASH_OUT"])]

# %%
fraud_types["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_types,x="type",hue="isFraud")
plt.title("fraud distribution by transaction type")
plt.show()

# %%
corr=df[["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest","balanceDiffOrig","balanceDiffDest","isFraud"]].corr()

# %%
corr
# Out:
#                    amount  oldbalanceOrg  ...  balanceDiffDest   isFraud
# amount           1.000000      -0.002762  ...         0.845964  0.076688
# oldbalanceOrg   -0.002762       1.000000  ...        -0.087032  0.010154
# newbalanceOrig  -0.007861       0.998803  ...        -0.094456 -0.008148
# oldbalanceDest   0.294137       0.066243  ...         0.232316 -0.005885
# newbalanceDest   0.459304       0.042029  ...         0.436191  0.000535
# balanceDiffOrig  0.102337      -0.220297  ...         0.169292  0.362472
# balanceDiffDest  0.845964      -0.087032  ...         1.000000  0.027028
# isFraud          0.076688       0.010154  ...         0.027028  1.000000
#
# [8 rows x 8 columns]

# %%
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt=".2f")
plt.title("correlation matrix")
plt.show()

# %%
zero_after_transfer=df[
    (df["newbalanceOrig"]==0) &
    (df["oldbalanceOrg"]>0)&
    (df["type"].isin(["TRANSFER","CASH_OUT"]))

]

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
zero_after_transfer.head()
# Out:
#         type     amount  ... balanceDiffOrig  balanceDiffDest
# 2   TRANSFER     181.00  ...           181.0             0.00
# 3   CASH_OUT     181.00  ...           181.0        -21182.00
# 15  CASH_OUT  229133.94  ...         15325.0         46430.44
# 19  TRANSFER  215310.30  ...           705.0        -22425.00
# 24  TRANSFER  311685.89  ...         10835.0       2712905.89
#
# [5 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#        type    amount  ... balanceDiffOrig  balanceDiffDest
# 0   PAYMENT   9839.64  ...         9839.64              0.0
# 1   PAYMENT   1864.28  ...         1864.28              0.0
# 2  TRANSFER    181.00  ...          181.00              0.0
# 3  CASH_OUT    181.00  ...          181.00         -21182.0
# 4   PAYMENT  11668.14  ...        11668.14              0.0
#
# [5 rows x 12 columns]

# %%
df_model=df.drop(["nameOrig","nameDest","isFlaggedFraud"],axis=1)

# %%
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  ...  isFraud  balanceDiffOrig  balanceDiffDest
# 0   PAYMENT   9839.64       170136.0  ...        0          9839.64              0.0
# 1   PAYMENT   1864.28        21249.0  ...        0          1864.28              0.0
# 2  TRANSFER    181.00          181.0  ...        1           181.00              0.0
# 3  CASH_OUT    181.00          181.0  ...        1           181.00         -21182.0
# 4   PAYMENT  11668.14        41554.0  ...        0         11668.14              0.0
#
# [5 rows x 9 columns]

# %%
catergorical=["type"]
numeric=["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest"]

# %%
y=df_model["isFraud"]
x=df_model.drop("isFraud",axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,stratify=y)

# %%
prepocessor=ColumnTransformer(
    transformers=[
        ("num",StandardScaler(), numeric),
        ("cat",OneHotEncoder(drop="first"), catergorical)
    ],
    remainder="drop"
)

# %%
pipeline=Pipeline([
    ("prep",prepocessor),
    ("clf",LogisticRegression (class_weight="balanced", max_iter=1000))

]

)

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred=pipeline.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.94      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1807547,   98775],
#        [    160,    2304]])

# %%
pipeline.score(x_test,y_test)*100
# Out:
# 94.81686265511168

# %%
import joblib


joblib.dump(pipeline,"fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']
